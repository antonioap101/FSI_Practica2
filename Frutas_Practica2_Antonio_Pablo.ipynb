# %% [markdown]
# # Reconocedor de lengua de signos
#
# Vamos a desarrollar una red que reconozca lengua de signos. Para ello, vamos a utilizar un dataset contenido en nuestra cuenta de Google Drive. Antes, debemos montar nuestro sistema de archivos de Google Drive para hacerlo accesible desde este *notebook*. Google nos solicitará permiso, tenemos que copiar y pegar el código que nos suministra.

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# Ahora ya es accesible

# %% [markdown]
# ¿Estoy realmente utilizando una GPU? Compruébalo en **Editar / Configuración del cuaderno** o **Entorno de ejecución / Cambiar tipo de entorno de ejecución**

# %%
import tensorflow as tf

# Verifica si TensorFlow tiene acceso a la GPU
physical_devices = tf.config.list_physical_devices('GPU')

if len(physical_devices) > 0:
    print(f"Keras/TensorFlow tiene acceso a la GPU -> {tf.test.gpu_device_name()}")
else:
    print("Keras/TensorFlow está utilizando la CPU.")
# Out:
# Keras/TensorFlow tiene acceso a la GPU -> /device:GPU:0

# %% [markdown]
# ## Importaciones necesarias

# %%
# IMPORTS --------------------------------------------------
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import random
import numpy as np
import tensorflow as tf
import os

# %%
# Establecer una semilla para reproducibilidad
seed_value = 42
random.seed(seed_value)        # Semilla para Python
np.random.seed(seed_value)     # Semilla para NumPy
tf.random.set_seed(seed_value) # Semilla para TensorFlow/Keras

# %%
from PIL import Image
import os


def resize_images_in_directory(directorio_imagenes, nuevas_dimensiones, resize=True):
    # Filtrar solo los archivos de imagen (puedes ajustar las extensiones según tus necesidades)
    extensiones_de_imagen = ['.jpg', '.jpeg', '.png', '.gif', '.bmp']

    # Obtener la lista de archivos en el directorio
    archivos = os.listdir(directorio_imagenes)
    archivos_de_imagen = [archivo for archivo in archivos if any(archivo.endswith(extension) for extension in extensiones_de_imagen)]

    # Iterar a través de los archivos de imagen en el directorio
    for archivo_imagen in archivos_de_imagen:
        ruta_completa = os.path.join(directorio_imagenes, archivo_imagen)
        try:
            with Image.open(ruta_completa) as img:
                dimensiones = img.size
                if dimensiones != nuevas_dimensiones and resize:
                    img = img.resize(nuevas_dimensiones, Image.ANTIALIAS)
                    img.save(ruta_completa)  # Guardar la imagen redimensionada
                    print(f'Imagen redimensionada: {archivo_imagen}, Dimensiones: {nuevas_dimensiones}')
                else: 
                    print(f'Imagen: {archivo_imagen}, Dimensiones: {dimensiones}')                
        except Exception as e:
            print(f'Error al procesar {archivo_imagen}: {str(e)}')

# Lista de directorios que contienen las imágenes
directorios_imagenes = [
    './datasets/fruit_classification/test/Apple/',
    './datasets/fruit_classification/test/Banana/',
    './datasets/fruit_classification/test/Grape/',
    './datasets/fruit_classification/test/Mango/',
    './datasets/fruit_classification/test/Strawberry',
    './datasets/fruit_classification/valid/Apple/',
    './datasets/fruit_classification/valid/Banana/',
    './datasets/fruit_classification/valid/Grape/',
    './datasets/fruit_classification/valid/Mango/',
    './datasets/fruit_classification/valid/Strawberry',
    './datasets/fruit_classification/train/Apple/',
    './datasets/fruit_classification/train/Banana/',
    './datasets/fruit_classification/train/Grape/',
    './datasets/fruit_classification/train/Mango/',
    './datasets/fruit_classification/train/Strawberry',
]
# Dimensiones deseadas
nuevas_dimensiones = (200, 200)

# Redimensionar imágenes en los directorios
for directorio_imagenes in directorios_imagenes:
    print(f'Procesando directorio: {directorio_imagenes}')
    resize_images_in_directory(directorio_imagenes, nuevas_dimensiones, resize=True)
# Out:
# Procesando directorio: ./datasets/fruit_classification/test/Apple/
# Imagen redimensionada: Apple (1029).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1046).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1052).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1080).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1086).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1095).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1169).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1199).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1229).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1234).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1236).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1279).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1332).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1333).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1341).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1354).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1378).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1400).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1431).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1440).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1464).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1476).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1483).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1506).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1510).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1523).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1529).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1538).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1582).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1645).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1650).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1655).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1755).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1782).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1785).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (183).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1860).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1931).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1935).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1942).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1952).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1957).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1977).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (209).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (221).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (234).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (236).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (238).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (24).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (259).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (270).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (339).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (346).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (387).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (426).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (467).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (480).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (511).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (518).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (522).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (575).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (58).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (6).png, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (620).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (627).jpeg, Dimensiones: (200, 200)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14248\2268245432.py:20: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   img = img.resize(nuevas_dimensiones, Image.ANTIALIAS)
# Imagen redimensionada: Apple (644).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (651).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (693).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (709).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (72).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (735).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (738).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (759).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (764).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (770).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (802).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (824).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (834).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (886).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (89).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (918).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (924).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (93).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (942).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (95).jpeg, Dimensiones: (200, 200)
# Procesando directorio: ./datasets/fruit_classification/test/Banana/
# Imagen redimensionada: Banana (2020).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (2029).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (2035).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (2045).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (2053).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (2056).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (2059).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (2062).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (2076).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (2123).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (2125).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (2128).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (2136).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (2141).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (2160).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (2246).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (2279).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (2324).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (2369).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (2378).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (2415).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (2433).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (2454).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (2461).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (2479).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (2496).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (2525).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (2538).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (2602).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (2617).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (2643).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (2645).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (2675).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (2679).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (2687).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (2698).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (2736).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (2749).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (2821).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (2828).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (2850).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (2918).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (2933).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (2973).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (2990).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (3095).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (3113).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (3123).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (3162).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (3189).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (3231).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (3240).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (3256).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (3272).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (3299).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (3313).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (3319).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (3366).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (3372).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (3395).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (3397).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (3403).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (3434).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (3445).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (3477).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (3535).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (3536).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (3541).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (3576).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (3608).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (3651).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (3674).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (3768).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (3776).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (3800).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (3802).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (3842).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (3861).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (3868).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (3877).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (3921).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (3929).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (3933).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (3959).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Banana (3974).jpeg, Dimensiones: (200, 200)
# Procesando directorio: ./datasets/fruit_classification/test/Grape/
# Imagen redimensionada: Grape (1031).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (1036).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (1053).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (1069).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (1095).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (1108).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (1126).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (1186).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (1207).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (121).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (1228).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (126).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (1293).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (1296).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (130).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (1311).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (1315).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (132).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (134).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (1354).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (1402).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (1430).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (146).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (1465).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (1489).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (1542).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (1592).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (1595).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (1598).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (161).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (1642).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (1679).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (1688).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (1693).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (1699).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (1708).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (1733).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (1740).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (1771).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (1795).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (1809).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (1829).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (1843).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (1870).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (188).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (1887).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (1908).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (1951).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (1978).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (1991).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (200).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (2009).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (24).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (253).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (265).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (294).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (31).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (311).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (314).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (349).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (353).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (360).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (390).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (413).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (414).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (423).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (449).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (460).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (478).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (483).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (530).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (549).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (613).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (646).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (713).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (716).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (777).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (843).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (844).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (859).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (882).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (899).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (941).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (98).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Grape (984).jpeg, Dimensiones: (200, 200)
# Procesando directorio: ./datasets/fruit_classification/test/Mango/
# Imagen redimensionada: Mango (1018).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (1034).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (1036).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (1065).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (1072).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (1109).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (1129).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (1150).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (1160).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (1171).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (1218).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (122).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (1223).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (1259).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (1294).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (1296).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (1347).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (1355).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (1369).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (1404).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (1426).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (1470).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (1473).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (1476).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (1504).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (1506).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (1514).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (1537).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (1540).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (1558).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (1570).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (163).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (1641).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (166).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (1663).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (1700).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (1741).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (176).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (177).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (1793).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (1829).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (1890).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (1918).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (1927).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (195).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (1968).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (1996).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (2).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (203).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (206).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (214).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (262).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (289).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (30).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (335).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (355).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (362).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (386).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (398).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (407).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (43).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (538).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (540).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (62).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (649).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (687).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (700).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (714).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (728).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (752).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (758).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (766).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (828).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (830).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (867).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (880).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (89).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (892).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (917).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (919).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (921).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (959).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (962).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (986).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Mango (996).jpeg, Dimensiones: (200, 200)
# Procesando directorio: ./datasets/fruit_classification/test/Strawberry
# Imagen redimensionada: Strawberry (1040).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (1048).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (1077).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (1158).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (1165).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (1177).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (1215).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (1221).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (1254).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (1262).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (1263).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (1268).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (1270).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (1300).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (1316).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (1328).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (1399).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (1430).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (1431).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (1450).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (151).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (1519).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (1567).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (1582).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (1583).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (1584).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (1607).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (1619).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (1624).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (1691).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (1703).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (1721).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (1730).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (177).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (1777).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (1785).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (1815).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (1817).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (1823).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (1832).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (1854).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (1855).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (1862).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (1916).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (193).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (1956).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (1999).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (208).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (273).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (282).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (304).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (326).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (335).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (345).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (366).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (4).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (40).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (404).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (422).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (428).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (440).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (445).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (454).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (458).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (502).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (510).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (554).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (581).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (60).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (612).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (618).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (65).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (661).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (68).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (752).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (760).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (794).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (808).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (811).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (848).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (861).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (884).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (977).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (980).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (989).jpeg, Dimensiones: (200, 200)
# Procesando directorio: ./datasets/fruit_classification/valid/Apple/
# Imagen redimensionada: Apple (1005).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1009).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (101).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1012).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1016).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (102).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1045).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1050).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1058).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1061).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1065).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1073).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1079).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1081).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1089).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1104).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1105).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1107).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1108).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1114).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1117).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1122).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1123).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1131).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1150).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1158).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1159).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1167).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1168).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1180).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1182).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1183).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1184).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1185).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (119).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1195).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1196).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1209).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (121).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1215).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1219).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1220).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1231).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (124).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1240).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1253).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1254).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1258).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1265).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1268).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1269).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1273).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (128).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1285).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1290).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1291).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1292).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1301).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1304).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1310).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1326).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1335).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1337).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1338).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1359).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1368).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1371).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1373).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1381).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1414).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1425).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1441).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1445).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1454).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1486).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1492).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1501).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1507).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1508).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1509).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1511).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1512).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1513).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (153).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1530).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1539).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (154).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1542).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1548).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1550).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1555).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1557).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1562).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1571).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1576).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (158).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1584).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1589).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1598).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1605).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1609).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (161).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1611).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1617).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1619).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1621).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1623).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1625).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1629).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1634).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1635).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1641).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1647).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1653).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1654).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1658).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1661).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1667).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1670).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1675).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1677).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1689).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1699).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1705).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1714).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1717).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1741).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1743).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1744).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1752).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1756).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1761).jpeg, Dimensiones: (200, 200)
# Imagen: Apple (1769).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (177).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1776).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1792).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1794).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1799).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1814).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1817).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1828).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1830).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1839).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1844).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1848).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1856).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1858).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1861).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1867).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1870).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1876).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1877).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1884).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1894).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (19).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1905).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1915).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (192).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1930).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1932).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1938).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1948).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (195).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1955).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1963).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1964).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1968).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1971).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (1980).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (199).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (20).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (200).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (206).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (225).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (245).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (247).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (256).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (271).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (284).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (288).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (289).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (294).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (296).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (297).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (300).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (306).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (313).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (331).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (338).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (344).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (356).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (36).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (362).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (372).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (373).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (375).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (377).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (383).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (385).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (391).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (400).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (402).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (405).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (410).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (412).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (413).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (42).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (428).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (43).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (436).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (445).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (446).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (45).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (451).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (465).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (469).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (478).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (481).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (486).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (494).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (506).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (510).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (514).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (524).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (529).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (536).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (537).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (545).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (549).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (554).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (559).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (568).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (571).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (573).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (584).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (594).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (599).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (603).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (607).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (610).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (632).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (640).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (645).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (649).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (655).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (683).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (687).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (689).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (69).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (690).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (694).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (7).png, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (701).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (703).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (718).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (731).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (742).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (743).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (750).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (754).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (755).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (769).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (778).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (781).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (794).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (819).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (820).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (821).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (823).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (827).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (831).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (837).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (839).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (849).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (85).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (864).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (872).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (874).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (876).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (881).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (882).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (885).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (894).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (897).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (898).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (90).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (913).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (915).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (916).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Apple (928).jpeg, Dimensiones: (200, 200)
# ...
# Imagen redimensionada: Strawberry (753).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (755).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (757).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (758).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (759).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (76).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (761).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (762).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (763).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (764).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (765).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (766).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (767).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (768).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (769).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (77).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (770).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (771).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (772).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (773).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (774).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (775).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (776).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (777).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (778).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (779).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (78).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (780).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (781).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (782).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (784).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (785).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (787).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (788).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (789).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (79).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (790).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (791).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (792).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (793).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (795).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (797).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (798).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (799).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (8).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (80).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (800).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (801).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (803).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (804).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (806).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (807).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (809).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (81).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (810).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (812).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (813).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (814).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (815).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (816).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (817).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (818).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (819).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (82).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (821).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (822).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (823).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (824).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (825).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (826).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (827).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (829).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (83).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (831).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (833).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (834).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (835).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (836).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (839).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (84).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (840).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (841).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (842).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (843).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (845).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (846).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (849).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (85).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (850).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (851).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (852).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (853).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (854).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (855).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (856).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (859).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (86).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (860).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (862).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (863).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (865).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (866).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (867).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (868).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (869).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (870).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (871).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (872).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (873).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (874).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (875).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (876).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (877).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (878).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (879).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (88).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (880).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (881).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (882).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (883).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (885).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (886).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (887).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (888).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (889).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (89).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (890).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (892).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (893).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (894).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (896).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (897).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (898).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (899).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (9).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (900).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (902).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (903).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (904).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (905).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (906).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (907).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (908).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (909).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (910).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (911).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (912).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (913).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (914).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (915).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (916).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (918).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (919).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (92).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (920).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (922).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (923).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (924).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (925).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (926).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (928).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (929).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (93).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (930).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (931).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (932).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (933).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (934).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (935).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (936).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (939).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (94).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (940).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (941).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (942).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (943).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (945).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (946).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (947).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (948).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (95).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (951).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (952).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (953).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (954).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (956).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (957).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (958).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (959).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (96).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (960).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (961).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (962).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (963).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (964).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (965).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (966).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (967).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (968).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (97).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (970).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (971).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (972).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (973).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (974).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (975).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (976).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (978).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (98).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (981).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (982).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (983).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (984).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (985).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (986).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (987).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (988).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (99).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (990).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (991).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (992).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (993).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (994).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (995).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (996).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (997).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (998).jpeg, Dimensiones: (200, 200)
# Imagen redimensionada: Strawberry (999).jpeg, Dimensiones: (200, 200)

# %% [markdown]
# ### Data augmentation

# %%
'''

from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing import image
from keras_preprocessing.image import load_img, img_to_array



image_size = (200, 200) 
batch_size = 16

# Configuración del generador de aumento de datos
data_augmentation = ImageDataGenerator(
    rescale=1./255,                 # Normalización de los valores de píxeles
    rotation_range=40,              # Grados de rotación aleatoria
    width_shift_range=0.1,          # Desplazamiento horizontal aleatorio
    height_shift_range=0.1,         # Desplazamiento vertical aleatorio
    shear_range=0.1,                # Cizalla aleatoria
    zoom_range=0.1,                 # Rango de zoom aleatorio
    channel_shift_range=5,         # Cambios aleatorios en los canales de colores
    brightness_range=[0.8,1.2],     # Rango de brillo aleatorio
    horizontal_flip=True,           # Activar volteo horizontal
    vertical_flip=True,             # Activar volteo vertical
    fill_mode='nearest'             # Modo de llenado para cuando se aplican transformaciones espaciales
)

# Directorios de entrenamiento y validación
train_dir = './datasets/coins_final/train'
valid_dir = './datasets/coins_final/valid'

# Directorios de salida para las imágenes aumentadas
augmented_train_dir = './datasets/coins_final/augmented_train'
augmented_valid_dir = './datasets/coins_final/augmented_valid'

# Función para guardar las imágenes aumentadas
def save_augmented_images(directory, augmented_directory, generator, num_images_per_file=5):
    # Crear el directorio si no existe
    if not os.path.exists(augmented_directory):
        os.makedirs(augmented_directory)
    
    for subdir in os.listdir(directory):
        subdirectory = os.path.join(directory, subdir)
        if os.path.isdir(subdirectory):
            augmented_subdir = os.path.join(augmented_directory, subdir)
            if not os.path.exists(augmented_subdir):
                os.makedirs(augmented_subdir)
            
            for file in os.listdir(subdirectory):
                file_path = os.path.join(subdirectory, file)
                image_obj = load_img(file_path)
                image_array = img_to_array(image_obj)
                image_array = image_array.reshape((1,) + image_array.shape)
                
                # Generar nuevas imágenes
                i = 0
                for batch in generator.flow(image_array, batch_size=1, save_to_dir=augmented_subdir, save_prefix=subdir, save_format='jpeg'):
                    i += 1
                    if i >= num_images_per_file:
                        break  # Guardar 5 imágenes y luego continuar con la siguiente imagen

# Aplicar aumento de datos al conjunto de entrenamiento y validación
save_augmented_images(train_dir, augmented_train_dir, data_augmentation)
save_augmented_images(valid_dir, augmented_valid_dir, data_augmentation)


# Creación de los generadores
train_gen = data_augmentation.flow_from_directory(
    train_dir,
    target_size=image_size,  # Asegúrate de que coincida con el tamaño de entrada de tu modelo
    batch_size=batch_size,
    class_mode='categorical'
)

valid_gen = data_augmentation.flow_from_directory(
    valid_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical'
)
'''
# Out:
# "\n\nfrom keras.preprocessing.image import ImageDataGenerator\nfrom keras.preprocessing import image\nfrom keras_preprocessing.image import load_img, img_to_array\n\n\n\nimage_size = (200, 200) \nbatch_size = 16\n\n# Configuración del generador de aumento de datos\ndata_augmentation = ImageDataGenerator(\n    rescale=1./255,                 # Normalización de los valores de píxeles\n    rotation_range=40,              # Grados de rotación aleatoria\n    width_shift_range=0.1,          # Desplazamiento horizontal aleatorio\n    height_shift_range=0.1,         # Desplazamiento vertical aleatorio\n    shear_range=0.1,                # Cizalla aleatoria\n    zoom_range=0.1,                 # Rango de zoom aleatorio\n    channel_shift_range=5,         # Cambios aleatorios en los canales de colores\n    brightness_range=[0.8,1.2],     # Rango de brillo aleatorio\n    horizontal_flip=True,           # Activar volteo horizontal\n    vertical_flip=True,             # Activar volteo vertical\n    fill_mode='nearest'             # Modo de llenado para cuando se aplican transformaciones espaciales\n)\n\n# Directorios de entrenamiento y validación\ntrain_dir = './datasets/coins_final/train'\nvalid_dir = './datasets/coins_final/valid'\n\n# Directorios de salida para las imágenes aumentadas\naugmented_train_dir = './datasets/coins_final/augmented_train'\naugmented_valid_dir = './datasets/coins_final/augmented_valid'\n\n# Función para guardar las imágenes aumentadas\ndef save_augmented_images(directory, augmented_directory, generator, num_images_per_file=5):\n    # Crear el directorio si no existe\n    if not os.path.exists(augmented_directory):\n        os.makedirs(augmented_directory)\n    \n    for subdir in os.listdir(directory):\n        subdirectory = os.path.join(directory, subdir)\n        if os.path.isdir(subdirectory):\n            augmented_subdir = os.path.join(augmented_directory, subdir)\n            if not os.path.exists(augmented_subdir):\n                os.makedirs(augmented_subdir)\n            \n            for file in os.listdir(subdirectory):\n                file_path = os.path.join(subdirectory, file)\n                image_obj = load_img(file_path)\n                image_array = img_to_array(image_obj)\n                image_array = image_array.reshape((1,) + image_array.shape)\n                \n                # Generar nuevas imágenes\n                i = 0\n                for batch in generator.flow(image_array, batch_size=1, save_to_dir=augmented_subdir, save_prefix=subdir, save_format='jpeg'):\n                    i += 1\n                    if i >= num_images_per_file:\n                        break  # Guardar 5 imágenes y luego continuar con la siguiente imagen\n\n# Aplicar aumento de datos al conjunto de entrenamiento y validación\nsave_augmented_images(train_dir, augmented_train_dir, data_augmentation)\nsave_augmented_images(valid_dir, augmented_valid_dir, data_augmentation)\n\n\n# Creación de los generadores\ntrain_gen = data_augmentation.flow_from_directory(\n    train_dir,\n    target_size=image_size,  # Asegúrate de que coincida con el tamaño de entrada de tu modelo\n    batch_size=batch_size,\n    class_mode='categorical'\n)\n\nvalid_gen = data_augmentation.flow_from_directory(\n    valid_dir,\n    target_size=image_size,\n    batch_size=batch_size,\n    class_mode='categorical'\n)\n"

# %%
# DATA SOURCE --------------------------------------------------
# '''
image_size = (100, 100) 
batch_size = 32
data_dir = os.path.join('./datasets', 'fruits', 'train')
train_dir = os.path.join('./datasets/fruit_classification/train') 
valid_dir = os.path.join('./datasets/fruit_classification/valid/') 
test_dir = os.path.join('./datasets/fruit_classification/test') 


train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    directory=train_dir,
    image_size=image_size,
    batch_size=batch_size,
    label_mode='categorical'
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    directory=valid_dir,
    image_size=image_size,
    batch_size=batch_size,
    label_mode='categorical'
)

test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    directory=test_dir,
    image_size=image_size,
    batch_size=batch_size,
    label_mode='categorical'
)

train_ds = train_ds.prefetch(buffer_size=32)
val_ds = val_ds.prefetch(buffer_size=32)
# '''
# Out:
# Found 8075 files belonging to 5 classes.
# Found 1500 files belonging to 5 classes.
# Found 425 files belonging to 5 classes.

# %%
from matplotlib.pyplot import imshow
import numpy as np
from PIL import Image

# %matplotlib inline

pil_im = Image.open('datasets/fruit_classification/train/Apple/Apple (1).jpeg', 'r')
imshow(np.asarray(pil_im))

# %%
# MODEL --------------------------------------------------

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Dense, Rescaling, Flatten
from tensorflow.keras.callbacks import EarlyStopping

model = Sequential([
    # La capa de rescaling se puede hacer como parte del preprocesamiento de los datos
    # Conv Layer 1
    Conv2D(64, (3, 3), activation='relu', input_shape=(100, 100, 3)),
    MaxPooling2D(2, 2),
    
    # Conv Layer 2
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    
    # Conv Layer 3
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Dropout(0.25),
    
    
    # Flattening the layers
    Flatten(),
    
    # Dense Layer 1
    Dense(128, activation='relu'),
    Dropout(0.5),
    
    # Output Layer
    Dense(5, activation='softmax')  # 8 clases correspondientes a tus frutas
])

model.compile(loss=tf.keras.losses.categorical_crossentropy,
              optimizer=tf.keras.optimizers.Adam(1e-3),
              metrics=['accuracy'])

# %%
# TRAINING --------------------------------------------------

epochs = 100

es = EarlyStopping(monitor='val_accuracy', mode='max', verbose=1, patience=10, restore_best_weights=True)

h = model.fit(
        train_ds, # train_gen, 
        epochs=epochs,
        validation_data=val_ds,
        callbacks = [es]
)
# Out:
# Epoch 1/100
# 253/253 [==============================] - 9s 22ms/step - loss: 3.0042 - accuracy: 0.3003 - val_loss: 1.4014 - val_accuracy: 0.4080
# Epoch 2/100
# 253/253 [==============================] - 5s 18ms/step - loss: 1.3560 - accuracy: 0.4100 - val_loss: 1.2546 - val_accuracy: 0.4633
# Epoch 3/100
# 253/253 [==============================] - 5s 18ms/step - loss: 1.2366 - accuracy: 0.4627 - val_loss: 1.2121 - val_accuracy: 0.4953
# Epoch 4/100
# 253/253 [==============================] - 5s 18ms/step - loss: 1.1913 - accuracy: 0.4971 - val_loss: 1.1442 - val_accuracy: 0.5253
# Epoch 5/100
# 253/253 [==============================] - 5s 18ms/step - loss: 1.1786 - accuracy: 0.5085 - val_loss: 1.1744 - val_accuracy: 0.5340
# Epoch 6/100
# 253/253 [==============================] - 5s 18ms/step - loss: 1.1352 - accuracy: 0.5215 - val_loss: 1.1090 - val_accuracy: 0.5373
# Epoch 7/100
# 253/253 [==============================] - 4s 17ms/step - loss: 1.1029 - accuracy: 0.5459 - val_loss: 1.0950 - val_accuracy: 0.5393
# Epoch 8/100
# 253/253 [==============================] - 5s 18ms/step - loss: 1.1062 - accuracy: 0.5485 - val_loss: 1.1327 - val_accuracy: 0.5133
# Epoch 9/100
# 253/253 [==============================] - 5s 18ms/step - loss: 1.0738 - accuracy: 0.5544 - val_loss: 1.0675 - val_accuracy: 0.5567
# Epoch 10/100
# 253/253 [==============================] - 5s 18ms/step - loss: 1.0704 - accuracy: 0.5643 - val_loss: 1.1095 - val_accuracy: 0.5507
# Epoch 11/100
# 253/253 [==============================] - 5s 18ms/step - loss: 1.0520 - accuracy: 0.5715 - val_loss: 1.0917 - val_accuracy: 0.5580
# Epoch 12/100
# 253/253 [==============================] - 5s 18ms/step - loss: 1.0268 - accuracy: 0.5747 - val_loss: 1.0696 - val_accuracy: 0.5727
# Epoch 13/100
# 253/253 [==============================] - 4s 17ms/step - loss: 1.0158 - accuracy: 0.5861 - val_loss: 1.0584 - val_accuracy: 0.5527
# Epoch 14/100
# 253/253 [==============================] - 5s 18ms/step - loss: 0.9781 - accuracy: 0.5964 - val_loss: 1.1103 - val_accuracy: 0.5533
# Epoch 15/100
# 253/253 [==============================] - 5s 18ms/step - loss: 0.9745 - accuracy: 0.6053 - val_loss: 1.0876 - val_accuracy: 0.5620
# Epoch 16/100
# 253/253 [==============================] - 5s 19ms/step - loss: 0.9316 - accuracy: 0.6152 - val_loss: 1.0984 - val_accuracy: 0.5707
# Epoch 17/100
# 253/253 [==============================] - 5s 19ms/step - loss: 0.8911 - accuracy: 0.6385 - val_loss: 1.0886 - val_accuracy: 0.5893
# Epoch 18/100
# 253/253 [==============================] - 5s 18ms/step - loss: 0.8956 - accuracy: 0.6471 - val_loss: 1.0515 - val_accuracy: 0.5920
# Epoch 19/100
# 253/253 [==============================] - 5s 20ms/step - loss: 0.8168 - accuracy: 0.6692 - val_loss: 1.0843 - val_accuracy: 0.5793
# Epoch 20/100
# 253/253 [==============================] - 5s 19ms/step - loss: 0.8058 - accuracy: 0.6873 - val_loss: 1.1433 - val_accuracy: 0.5873
# Epoch 21/100
# 253/253 [==============================] - 5s 19ms/step - loss: 0.7680 - accuracy: 0.6961 - val_loss: 1.0901 - val_accuracy: 0.5953
# Epoch 22/100
# 253/253 [==============================] - 5s 18ms/step - loss: 0.7397 - accuracy: 0.7092 - val_loss: 1.2072 - val_accuracy: 0.5787
# Epoch 23/100
# 253/253 [==============================] - 4s 18ms/step - loss: 0.7060 - accuracy: 0.7264 - val_loss: 1.0718 - val_accuracy: 0.6153
# Epoch 24/100
# 253/253 [==============================] - 5s 18ms/step - loss: 0.6838 - accuracy: 0.7346 - val_loss: 1.1938 - val_accuracy: 0.6067
# Epoch 25/100
# 253/253 [==============================] - 4s 17ms/step - loss: 0.6543 - accuracy: 0.7493 - val_loss: 1.2829 - val_accuracy: 0.5833
# Epoch 26/100
# 253/253 [==============================] - 4s 17ms/step - loss: 0.6471 - accuracy: 0.7555 - val_loss: 1.1849 - val_accuracy: 0.6027
# Epoch 27/100
# 253/253 [==============================] - 5s 18ms/step - loss: 0.5815 - accuracy: 0.7729 - val_loss: 1.2290 - val_accuracy: 0.5993
# Epoch 28/100
# 253/253 [==============================] - 5s 18ms/step - loss: 0.5378 - accuracy: 0.7947 - val_loss: 1.3125 - val_accuracy: 0.6040
# Epoch 29/100
# 253/253 [==============================] - 5s 18ms/step - loss: 0.5597 - accuracy: 0.7915 - val_loss: 1.2439 - val_accuracy: 0.6040
# Epoch 30/100
# 253/253 [==============================] - 5s 18ms/step - loss: 0.5687 - accuracy: 0.7861 - val_loss: 1.2396 - val_accuracy: 0.5913
# Epoch 31/100
# 253/253 [==============================] - 5s 18ms/step - loss: 0.5153 - accuracy: 0.8042 - val_loss: 1.3212 - val_accuracy: 0.5853
# Epoch 32/100
# 253/253 [==============================] - 5s 18ms/step - loss: 0.4889 - accuracy: 0.8203 - val_loss: 1.3534 - val_accuracy: 0.6133
# Epoch 33/100
# 252/253 [============================>.] - ETA: 0s - loss: 0.4814 - accuracy: 0.8237Restoring model weights from the end of the best epoch: 23.
# 253/253 [==============================] - 5s 19ms/step - loss: 0.4814 - accuracy: 0.8238 - val_loss: 1.5335 - val_accuracy: 0.6020
# Epoch 33: early stopping

# %%
import matplotlib.pyplot as plt

def generatePlot(history):
    # Extracción de datos
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(1, len(acc) + 1)

    # Creación del gráfico de accuracy
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.plot(epochs, acc, 'b', label='Training')
    plt.plot(epochs, val_acc, 'r', label='Validation')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    # Creación del gráfico de loss
    plt.subplot(1, 2, 2)
    plt.plot(epochs, loss, 'b', label='Training')
    plt.plot(epochs, val_loss, 'r', label='Validation')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()
    

# Plots separados    
generatePlot(h)

# Plot conjunto
plt.plot(h.history['accuracy'])
plt.plot(h.history['val_accuracy'])
plt.plot(h.history['loss'])
plt.plot(h.history['val_loss'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training Accuracy', 'Validation Accuracy','Training Loss','Validation Loss'], loc='upper right')
plt.show()

# %% [markdown]
# ## Evaluación de los resultados

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

#for x, y in val_ds:
#  print(len(y))


results = np.concatenate([(y, model.predict(x=x)) for x, y in val_ds], axis=1)

predictions = np.argmax(results[0], axis=1)
labels = np.argmax(results[1], axis=1)

cf_matrix = confusion_matrix(labels, predictions)

# Crear un mapa de calor con etiquetas en los ejes
plt.figure(figsize=(8, 6))
sns.heatmap(cf_matrix, annot=True, fmt="d", cmap="Blues")

plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix with Valid')
plt.show()


print(classification_report(labels, predictions, digits = 4))
# Out:
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 54ms/step
#               precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000        61
#            1     1.0000    1.0000    1.0000        89
#            2     1.0000    1.0000    1.0000        96
#            3     1.0000    1.0000    1.0000        79
#            4     1.0000    1.0000    1.0000        88
#            5     1.0000    1.0000    1.0000        77
#            6     1.0000    1.0000    1.0000       103
#            7     1.0000    1.0000    1.0000        88
#
#     accuracy                         1.0000       681
#    macro avg     1.0000    1.0000    1.0000       681
# weighted avg     1.0000    1.0000    1.0000       681

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

#for x, y in val_ds:
#  print(len(y))


results = np.concatenate([(y, model.predict(x=x)) for x, y in test_ds], axis=1)

predictions = np.argmax(results[0], axis=1)
labels = np.argmax(results[1], axis=1)

cf_matrix = confusion_matrix(labels, predictions)

# Crear un mapa de calor con etiquetas en los ejes
plt.figure(figsize=(8, 6))
sns.heatmap(cf_matrix, annot=True, fmt="d", cmap="Blues")

plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix with Test')
plt.show()


print(classification_report(labels, predictions, digits = 4))
# Out:
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 153ms/step
#               precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000        42
#            1     1.0000    1.0000    1.0000        49
#            2     1.0000    1.0000    1.0000        46
#            3     1.0000    1.0000    1.0000        46
#            4     1.0000    1.0000    1.0000        49
#            5     1.0000    1.0000    1.0000        47
#            6     1.0000    1.0000    1.0000        49
#            7     1.0000    1.0000    1.0000        47
#
#     accuracy                         1.0000       375
#    macro avg     1.0000    1.0000    1.0000       375
# weighted avg     1.0000    1.0000    1.0000       375
